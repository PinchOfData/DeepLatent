# %% [markdown]
# # DeepLatent with Colored MNIST: Multimodal Generation Test
#
# This notebook demonstrates:
# 1. **Colored MNIST Dataset Creation** - MNIST digits with color shifts as covariates
# 2. **Multimodal Learning** - Both images and text descriptions
# 3. **FiLM Conditioning** - Images conditioned on color covariates
# 4. **Content Generation** - Generate new samples with different covariate configurations
# 5. **Topic Modeling** - Across visual and textual modalities

# %% [markdown]
# ## Setup and Imports

# %%
import torch.nn.functional as F
import torch
import numpy as np
import pandas as pd
from PIL import Image
import os
import tempfile
from sklearn.feature_extraction.text import CountVectorizer
from typing import List, Tuple

# Handle imports gracefully
try:
    import matplotlib.pyplot as plt
    MATPLOTLIB_AVAILABLE = True
    print("✓ Matplotlib available")
except ImportError:
    print("⚠ Warning: matplotlib not available")
    MATPLOTLIB_AVAILABLE = False

try:
    import torchvision
    import torchvision.transforms as transforms
    from torchvision.datasets import MNIST
    TORCHVISION_AVAILABLE = True
    print("✓ Torchvision available")
except Exception as e:
    print(f"⚠ Warning: torchvision not available, will use synthetic data")
    TORCHVISION_AVAILABLE = False

# Import DeepLatent classes
from deeplatent import Corpus, DeepLatent

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {'CUDA' if torch.cuda.is_available() else 'CPU'}")
# Out:
# ✓ Matplotlib available
# ✓ Torchvision available
# PyTorch version: 2.8.0+cu128
# Device: CUDA

# %% [markdown]
# ## Define Transform Classes (Fallback for Missing Torchvision)

# %%
if not TORCHVISION_AVAILABLE:
    # Define minimal transforms class for fallback
    class transforms:
        @staticmethod
        class Compose:
            def __init__(self, transforms_list):
                self.transforms = transforms_list
            def __call__(self, x):
                for t in self.transforms:
                    x = t(x)
                return x
        
        @staticmethod
        class ToTensor:
            def __call__(self, pic):
                if isinstance(pic, np.ndarray):
                    return torch.from_numpy(pic.transpose((2, 0, 1))).float() / 255.0
                elif isinstance(pic, Image.Image):
                    return torch.from_numpy(np.array(pic)).float().unsqueeze(0) / 255.0
                return pic
        
        @staticmethod
        class ToPILImage:
            def __call__(self, tensor):
                if tensor.dim() == 3:
                    np_array = (tensor.permute(1, 2, 0).numpy() * 255).astype(np.uint8)
                    return Image.fromarray(np_array)
                else:
                    np_array = (tensor.numpy() * 255).astype(np.uint8)
                    return Image.fromarray(np_array, mode='L')
        
        @staticmethod
        class Resize:
            def __init__(self, size):
                self.size = size if isinstance(size, tuple) else (size, size)
            def __call__(self, img):
                return img.resize(self.size)
    
    print("✓ Fallback transforms defined")

# %% [markdown]
# ## Configuration

# %%
# Configuration parameters
CONFIG = {
    'n_samples': 25000,  # Number of MNIST samples to generate
    'colors': ['red', 'green', 'blue', 'yellow'],
    'n_topics': 10,
    'num_epochs': 100,  # Reduced for notebook
    'batch_size': 64,
    'image_size': (28, 28),  # Smaller for faster training
    'w_prior':10,
    'device': torch.device("cuda" if torch.cuda.is_available() else "cpu")
}

print(f"Configuration: {CONFIG}")
# Out:
# Configuration: {'n_samples': 25000, 'colors': ['red', 'green', 'blue', 'yellow'], 'n_topics': 10, 'num_epochs': 100, 'batch_size': 64, 'image_size': (28, 28), 'w_prior': 10, 'device': device(type='cuda')}

# %% [markdown]
# ## Colored MNIST Dataset Creation

# %%
class ColoredMNISTDataset:
    """Create MNIST dataset with color shifts and text descriptions."""
    
    def __init__(self, n_samples: int = 1000, colors: List[str] = None):
        self.n_samples = n_samples
        self.colors = colors or ['red', 'green', 'blue', 'yellow']
        self.color_values = {
            'red': [1.0, 0.3, 0.3],
            'green': [0.3, 1.0, 0.3], 
            'blue': [0.3, 0.3, 1.0],
            'yellow': [1.0, 1.0, 0.3],
            'purple': [0.8, 0.3, 0.8],
            'orange': [1.0, 0.6, 0.2],
            'cyan': [0.3, 0.8, 0.8],
            'pink': [1.0, 0.6, 0.8]
        }
        
        # Create temporary directory for images
        self.temp_dir = tempfile.mkdtemp()
        print(f"Creating colored MNIST images in: {self.temp_dir}")
        
        # Generate dataset
        self.data = self._generate_colored_mnist()
    
    def _generate_colored_mnist(self) -> pd.DataFrame:
        """Generate colored MNIST images with text descriptions."""
        
        if TORCHVISION_AVAILABLE:
            # Load MNIST dataset using torchvision
            transform = transforms.Compose([transforms.ToTensor()])
            mnist_dataset = MNIST(root='./data', train=True, download=True, transform=transform)
        else:
            # Fallback: create synthetic MNIST-like data
            print("Using synthetic MNIST-like data (torchvision not available)")
            mnist_dataset = self._create_synthetic_mnist()
        
        data_records = []
        digit_names = ['zero', 'one', 'two', 'three', 'four', 
                      'five', 'six', 'seven', 'eight', 'nine']
        
        np.random.seed(42)  # For reproducibility
        torch.manual_seed(42)
        
        for i in range(self.n_samples):
            # Sample random MNIST image
            idx = np.random.randint(0, len(mnist_dataset))
            
            if TORCHVISION_AVAILABLE:
                mnist_img, digit_label = mnist_dataset[idx]
            else:
                mnist_img, digit_label = mnist_dataset[idx]
            
            # Sample random color
            color_name = np.random.choice(self.colors)
            color_rgb = self.color_values[color_name]
            
            # Convert grayscale MNIST to colored RGB
            colored_img = self._apply_color_to_mnist(mnist_img, color_rgb)
            
            # Save colored image
            img_filename = f"mnist_{i:04d}_digit{digit_label}_color{color_name}.png"
            img_path = os.path.join(self.temp_dir, img_filename)
            
            # Convert tensor to PIL and save
            img_pil = transforms.ToPILImage()(colored_img)
            img_pil.save(img_path)
            
            # Create text description
            digit_name = digit_names[digit_label]
            text_description = f"A {color_name} colored number {digit_name}"
            
            # Add some variation to text
            variations = [
                f"The digit {digit_name} in {color_name} color",
                f"Number {digit_name} colored {color_name}",
                f"A {color_name} {digit_name}",
                f"{color_name.capitalize()} digit {digit_name}"
            ]
            if np.random.random() > 0.5:
                text_description = np.random.choice(variations)
            
            data_records.append({
                'sample_id': i,
                'image_path': img_path,
                'digit_label': digit_label,
                'digit_name': digit_name,
                'color_name': color_name,
                'color_r': color_rgb[0],
                'color_g': color_rgb[1], 
                'color_b': color_rgb[2],
                'text_description': text_description,
                'is_even': digit_label % 2 == 0,
                'digit_category': 'low' if digit_label < 5 else 'high'
            })
            
            if (i + 1) % 100 == 0:
                print(f"Generated {i + 1}/{self.n_samples} samples")
        
        df = pd.DataFrame(data_records)
        print(f"✓ Created dataset with {len(df)} samples")
        
        return df
    
    def _create_synthetic_mnist(self):
        """Create synthetic MNIST-like dataset when torchvision is not available."""
        print("Creating synthetic digit-like images...")
        
        class SyntheticMNIST:
            def __init__(self, n_samples=1000):
                self.data = []
                np.random.seed(42)
                
                for i in range(n_samples):
                    digit_label = i % 10
                    img = self._create_digit_pattern(digit_label)
                    tensor = torch.from_numpy(img).float().unsqueeze(0)
                    self.data.append((tensor, digit_label))
            
            def _create_digit_pattern(self, digit):
                """Create simple patterns that roughly resemble digits."""
                img = np.zeros((28, 28), dtype=np.float32)
                
                if digit == 0:  # Circle
                    center = (14, 14)
                    for i in range(28):
                        for j in range(28):
                            dist = np.sqrt((i - center[0])**2 + (j - center[1])**2)
                            if 8 <= dist <= 12:
                                img[i, j] = 1.0
                elif digit == 1:  # Vertical line
                    img[4:24, 12:16] = 1.0
                # Add more digit patterns...
                
                # Add some noise for realism
                noise = np.random.normal(0, 0.05, (28, 28))
                img = np.clip(img + noise, 0, 1)
                
                return img
            
            def __len__(self):
                return len(self.data)
            
            def __getitem__(self, idx):
                return self.data[idx]
        
        return SyntheticMNIST(1000)
    
    def _apply_color_to_mnist(self, mnist_tensor: torch.Tensor, color_rgb: List[float]) -> torch.Tensor:
        """Apply color tint to grayscale MNIST image."""
        # Convert grayscale to RGB by repeating channel
        rgb_img = mnist_tensor.repeat(3, 1, 1)  # [3, H, W]
        
        # Apply color tint by element-wise multiplication
        for channel in range(3):
            rgb_img[channel] *= color_rgb[channel]
        
        # Add some background color variation
        background_intensity = 0.1
        for channel in range(3):
            background = torch.ones_like(rgb_img[channel]) * background_intensity * color_rgb[channel]
            rgb_img[channel] = torch.where(rgb_img[channel] < 0.1, background, rgb_img[channel])
        
        return rgb_img
    
    def cleanup(self):
        """Remove temporary image files."""
        import shutil
        shutil.rmtree(self.temp_dir)
        print(f"Cleaned up temporary directory: {self.temp_dir}")

print("✓ ColoredMNISTDataset class defined")
# Out:
# ✓ ColoredMNISTDataset class defined

# %% [markdown]
# ## Image Transform Function

# %%
def mnist_image_transform_function(image_paths: List[str]) -> torch.Tensor:
    """Transform function for MNIST images."""
    transform = transforms.Compose([
        transforms.Resize(CONFIG['image_size']),
        transforms.ToTensor(),
    ])
    
    processed_images = []
    for path in image_paths:
        try:
            img = Image.open(path).convert('RGB')
            tensor = transform(img)
            processed_images.append(tensor)
        except Exception as e:
            print(f"Error loading {path}: {e}")
            # Fallback: zero tensor
            processed_images.append(torch.zeros(3, *CONFIG['image_size']))
    
    # For single image (lazy loading), return the tensor directly
    if len(processed_images) == 1:
        return processed_images[0]
    
    # For batch processing, return stacked tensor
    return torch.stack(processed_images)

print("✓ Image transform function defined")
# Out:
# ✓ Image transform function defined

# %% [markdown]
# ## Generate Dataset

# %%
# Generate colored MNIST dataset
print("Generating colored MNIST dataset...")
dataset = ColoredMNISTDataset(n_samples=CONFIG['n_samples'], colors=CONFIG['colors'])
df = dataset.data

# Display dataset statistics
print(f"\nDataset Statistics:")
print(f"- Total samples: {len(df)}")
print(f"- Colors distribution: {df['color_name'].value_counts().to_dict()}")
print(f"- Digits distribution: {df['digit_label'].value_counts().to_dict()}")

# Show some sample descriptions
print(f"\nSample text descriptions:")
for i in range(5):
    print(f"  {i+1}. {df.iloc[i]['text_description']}")

# Display first few rows
df.head()
# Out:
# Generating colored MNIST dataset...
# Creating colored MNIST images in: /tmp/tmp2thi51e5
# Generated 100/25000 samples
# Generated 200/25000 samples
# Generated 300/25000 samples
# Generated 400/25000 samples
# Generated 500/25000 samples
# Generated 600/25000 samples
# Generated 700/25000 samples
# Generated 800/25000 samples
# Generated 900/25000 samples
# Generated 1000/25000 samples
# Generated 1100/25000 samples
# Generated 1200/25000 samples
# Generated 1300/25000 samples
# Generated 1400/25000 samples
# Generated 1500/25000 samples
# Generated 1600/25000 samples
# Generated 1700/25000 samples
# Generated 1800/25000 samples
# Generated 1900/25000 samples
# Generated 2000/25000 samples
# Generated 2100/25000 samples
# Generated 2200/25000 samples
# Generated 2300/25000 samples
# Generated 2400/25000 samples
# Generated 2500/25000 samples
# Generated 2600/25000 samples
# Generated 2700/25000 samples
# Generated 2800/25000 samples
# Generated 2900/25000 samples
# Generated 3000/25000 samples
# Generated 3100/25000 samples
# Generated 3200/25000 samples
# Generated 3300/25000 samples
# Generated 3400/25000 samples
# Generated 3500/25000 samples
# Generated 3600/25000 samples
# Generated 3700/25000 samples
# Generated 3800/25000 samples
# Generated 3900/25000 samples
# Generated 4000/25000 samples
# Generated 4100/25000 samples
# Generated 4200/25000 samples
# Generated 4300/25000 samples
# Generated 4400/25000 samples
# Generated 4500/25000 samples
# Generated 4600/25000 samples
# Generated 4700/25000 samples
# Generated 4800/25000 samples
# Generated 4900/25000 samples
# Generated 5000/25000 samples
# Generated 5100/25000 samples
# Generated 5200/25000 samples
# Generated 5300/25000 samples
# Generated 5400/25000 samples
# Generated 5500/25000 samples
# Generated 5600/25000 samples
# Generated 5700/25000 samples
# Generated 5800/25000 samples
# Generated 5900/25000 samples
# Generated 6000/25000 samples
# Generated 6100/25000 samples
# Generated 6200/25000 samples
# Generated 6300/25000 samples
# Generated 6400/25000 samples
# Generated 6500/25000 samples
# Generated 6600/25000 samples
# Generated 6700/25000 samples
# Generated 6800/25000 samples
# Generated 6900/25000 samples
# Generated 7000/25000 samples
# Generated 7100/25000 samples
# Generated 7200/25000 samples
# Generated 7300/25000 samples
# Generated 7400/25000 samples
# Generated 7500/25000 samples
# Generated 7600/25000 samples
# Generated 7700/25000 samples
# Generated 7800/25000 samples
# Generated 7900/25000 samples
# Generated 8000/25000 samples
# Generated 8100/25000 samples
# Generated 8200/25000 samples
# Generated 8300/25000 samples
# Generated 8400/25000 samples
# Generated 8500/25000 samples
# Generated 8600/25000 samples
# Generated 8700/25000 samples
# Generated 8800/25000 samples
# Generated 8900/25000 samples
# Generated 9000/25000 samples
# Generated 9100/25000 samples
# Generated 9200/25000 samples
# Generated 9300/25000 samples
# Generated 9400/25000 samples
# Generated 9500/25000 samples
# Generated 9600/25000 samples
# Generated 9700/25000 samples
# Generated 9800/25000 samples
# Generated 9900/25000 samples
# Generated 10000/25000 samples
# Generated 10100/25000 samples
# Generated 10200/25000 samples
# Generated 10300/25000 samples
# Generated 10400/25000 samples
# Generated 10500/25000 samples
# Generated 10600/25000 samples
# Generated 10700/25000 samples
# Generated 10800/25000 samples
# Generated 10900/25000 samples
# Generated 11000/25000 samples
# Generated 11100/25000 samples
# Generated 11200/25000 samples
# Generated 11300/25000 samples
# Generated 11400/25000 samples
# Generated 11500/25000 samples
# Generated 11600/25000 samples
# Generated 11700/25000 samples
# Generated 11800/25000 samples
# Generated 11900/25000 samples
# Generated 12000/25000 samples
# Generated 12100/25000 samples
# Generated 12200/25000 samples
# Generated 12300/25000 samples
# Generated 12400/25000 samples
# Generated 12500/25000 samples
# Generated 12600/25000 samples
# Generated 12700/25000 samples
# Generated 12800/25000 samples
# Generated 12900/25000 samples
# Generated 13000/25000 samples
# Generated 13100/25000 samples
# Generated 13200/25000 samples
# Generated 13300/25000 samples
# Generated 13400/25000 samples
# Generated 13500/25000 samples
# Generated 13600/25000 samples
# Generated 13700/25000 samples
# Generated 13800/25000 samples
# Generated 13900/25000 samples
# Generated 14000/25000 samples
# Generated 14100/25000 samples
# Generated 14200/25000 samples
# Generated 14300/25000 samples
# Generated 14400/25000 samples
# Generated 14500/25000 samples
# Generated 14600/25000 samples
# Generated 14700/25000 samples
# Generated 14800/25000 samples
# Generated 14900/25000 samples
# Generated 15000/25000 samples
# Generated 15100/25000 samples
# Generated 15200/25000 samples
# Generated 15300/25000 samples
# Generated 15400/25000 samples
# Generated 15500/25000 samples
# Generated 15600/25000 samples
# Generated 15700/25000 samples
# Generated 15800/25000 samples
# Generated 15900/25000 samples
# Generated 16000/25000 samples
# Generated 16100/25000 samples
# Generated 16200/25000 samples
# Generated 16300/25000 samples
# Generated 16400/25000 samples
# Generated 16500/25000 samples
# Generated 16600/25000 samples
# Generated 16700/25000 samples
# Generated 16800/25000 samples
# Generated 16900/25000 samples
# Generated 17000/25000 samples
# Generated 17100/25000 samples
# Generated 17200/25000 samples
# Generated 17300/25000 samples
# Generated 17400/25000 samples
# Generated 17500/25000 samples
# Generated 17600/25000 samples
# Generated 17700/25000 samples
# Generated 17800/25000 samples
# Generated 17900/25000 samples
# Generated 18000/25000 samples
# Generated 18100/25000 samples
# Generated 18200/25000 samples
# Generated 18300/25000 samples
# Generated 18400/25000 samples
# Generated 18500/25000 samples
# Generated 18600/25000 samples
# Generated 18700/25000 samples
# Generated 18800/25000 samples
# Generated 18900/25000 samples
# Generated 19000/25000 samples
# Generated 19100/25000 samples
# Generated 19200/25000 samples
# Generated 19300/25000 samples
# Generated 19400/25000 samples
# Generated 19500/25000 samples
# Generated 19600/25000 samples
# Generated 19700/25000 samples
# Generated 19800/25000 samples
# Generated 19900/25000 samples
# Generated 20000/25000 samples
# Generated 20100/25000 samples
# Generated 20200/25000 samples
# Generated 20300/25000 samples
# Generated 20400/25000 samples
# Generated 20500/25000 samples
# Generated 20600/25000 samples
# Generated 20700/25000 samples
# Generated 20800/25000 samples
# Generated 20900/25000 samples
# Generated 21000/25000 samples
# Generated 21100/25000 samples
# Generated 21200/25000 samples
# Generated 21300/25000 samples
# Generated 21400/25000 samples
# Generated 21500/25000 samples
# Generated 21600/25000 samples
# Generated 21700/25000 samples
# Generated 21800/25000 samples
# Generated 21900/25000 samples
# Generated 22000/25000 samples
# Generated 22100/25000 samples
# Generated 22200/25000 samples
# Generated 22300/25000 samples
# Generated 22400/25000 samples
# Generated 22500/25000 samples
# Generated 22600/25000 samples
# Generated 22700/25000 samples
# Generated 22800/25000 samples
# Generated 22900/25000 samples
# Generated 23000/25000 samples
# Generated 23100/25000 samples
# Generated 23200/25000 samples
# Generated 23300/25000 samples
# Generated 23400/25000 samples
# Generated 23500/25000 samples
# Generated 23600/25000 samples
# Generated 23700/25000 samples
# Generated 23800/25000 samples
# Generated 23900/25000 samples
# Generated 24000/25000 samples
# Generated 24100/25000 samples
# Generated 24200/25000 samples
# Generated 24300/25000 samples
# Generated 24400/25000 samples
# Generated 24500/25000 samples
# Generated 24600/25000 samples
# Generated 24700/25000 samples
# Generated 24800/25000 samples
# Generated 24900/25000 samples
# Generated 25000/25000 samples
# ✓ Created dataset with 25000 samples
#
# Dataset Statistics:
# - Total samples: 25000
# - Colors distribution: {np.str_('blue'): 6287, np.str_('green'): 6284, np.str_('yellow'): 6230, np.str_('red'): 6199}
# - Digits distribution: {1: 2899, 7: 2580, 9: 2521, 2: 2519, 6: 2490, 0: 2478, 4: 2447, 3: 2444, 8: 2391, 5: 2231}
#
# Sample text descriptions:
#   1. A yellow four
#   2. Number three colored red
#   3. A blue colored number four
#   4. Red digit six
#   5. A green colored number one
#    sample_id                                         image_path  digit_label  \
# 0          0  /tmp/tmp2thi51e5/mnist_0000_digit4_coloryellow...            4
# 1          1    /tmp/tmp2thi51e5/mnist_0001_digit3_colorred.png            3
# 2          2   /tmp/tmp2thi51e5/mnist_0002_digit4_colorblue.png            4
# 3          3    /tmp/tmp2thi51e5/mnist_0003_digit6_colorred.png            6
# 4          4  /tmp/tmp2thi51e5/mnist_0004_digit1_colorgreen.png            1
#
#   digit_name color_name  color_r  color_g  color_b  \
# 0       four     yellow      1.0      1.0      0.3
# 1      three        red      1.0      0.3      0.3
# 2       four       blue      0.3      0.3      1.0
# 3        six        red      1.0      0.3      0.3
# 4        one      green      0.3      1.0      0.3
#
#              text_description  is_even digit_category
# 0               A yellow four     True            low
# 1    Number three colored red    False            low
# 2  A blue colored number four     True            low
# 3               Red digit six     True           high
# 4  A green colored number one    False            low

# %% [markdown]
# ## Visualize Sample Images

# %%
if MATPLOTLIB_AVAILABLE:
    # Visualize some colored MNIST samples
    fig, axes = plt.subplots(2, 4, figsize=(12, 6))
    axes = axes.flatten()
    
    for i in range(8):
        sample = df.iloc[i]
        img = Image.open(sample['image_path'])
        
        axes[i].imshow(img)
        axes[i].set_title(f"Digit {sample['digit_label']} ({sample['color_name']})")
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.title('Sample Colored MNIST Images', y=1.02, fontsize=16)
    plt.show()
else:
    print("Matplotlib not available - skipping visualization")

# %% [markdown]
# ## Create Multimodal Corpus

# %%
# Create corpus with both images and text
print("Creating multimodal corpus...")

modalities = {
    "text": {
        "views": {
            "bow": {
                "type": "bow",
                "column": "text_description",
                "vectorizer": CountVectorizer()
            }
        }
    },
    "visual": {
        "views": {
            "colored_mnist": {
                "type": "image",
                "column": "image_path",
                "transform_fn": mnist_image_transform_function
            }
        }
    }
}

corpus = Corpus(
    df,
    modalities=modalities,
    prevalence="~ C(color_name)",
    content="~ C(color_name)"  
)

train_corpus = Corpus(
    df.iloc[0:19999],
    modalities=modalities,
    prevalence="~ C(color_name)",
    content="~ C(color_name)"  
)

test_corpus = Corpus(
    df.iloc[20000:24999],
    modalities=modalities,
    prevalence="~ C(color_name)",
    content="~ C(color_name)"  
)

print(f"✓ Corpus created with {len(corpus)} samples")
print(f"Prevalence covariates shape: {corpus.M_prevalence_covariates.shape}")
print(f"Content covariates shape: {corpus.M_content_covariates.shape}")
print(f"Prevalence covariate names: {corpus.prevalence_colnames}")
print(f"Content covariate names: {corpus.content_colnames}")
# Out:
# Creating multimodal corpus...
# ✓ Corpus created with 25000 samples
# Prevalence covariates shape: (25000, 4)
# Content covariates shape: (25000, 4)
# Prevalence covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']
# Content covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']

# %% [markdown]
# ## Configure Model Architecture

# %%
# Configure model architecture
print("Configuring model architecture...")

encoder_args = {
    "visual_colored_mnist": {
        "input_channels": 3,
        "hidden_dims": [32, 64, 128, 256],      
        "fc_hidden_dims": [256],          
        "activation": "relu",
        "dropout": 0.1,
        "use_batch_norm": True,
        "input_size": CONFIG['image_size']
    }
}

decoder_args = {
    "visual_colored_mnist": {
        "output_channels": 3,
        "hidden_dims": [256, 128, 64, 32],      
        "output_size": CONFIG['image_size'],
        "fc_hidden_dims": [256],
        "activation": "relu",
        "use_batch_norm": True,
    }
}

print(f"✓ Architecture configured")
print(f"Encoder args: {encoder_args}")
print(f"Decoder args: {decoder_args}")
# Out:
# Configuring model architecture...
# ✓ Architecture configured
# Encoder args: {'visual_colored_mnist': {'input_channels': 3, 'hidden_dims': [32, 64, 128, 256], 'fc_hidden_dims': [256], 'activation': 'relu', 'dropout': 0.1, 'use_batch_norm': True, 'input_size': (28, 28)}}
# Decoder args: {'visual_colored_mnist': {'output_channels': 3, 'hidden_dims': [256, 128, 64, 32], 'output_size': (28, 28), 'fc_hidden_dims': [256], 'activation': 'relu', 'use_batch_norm': True}}

# %% [markdown]
# ## Train Multimodal Model

# %%
# Create and train the model
print("Creating and training GTM model...")

model = DeepLatent(
    train_data=train_corpus,
    test_data=test_corpus,
    n_factors=CONFIG['n_topics'],
    ae_type="wae",
    latent_factor_prior='gaussian',
    update_prior=False,
    encoder_args=encoder_args,
    decoder_args=decoder_args,
    fusion="moe_average",
    num_epochs=CONFIG['num_epochs'],
    batch_size=CONFIG['batch_size'],
    print_every_n_epochs=5,
    patience=5,  
    w_prior=CONFIG['w_prior'],
    device=CONFIG['device']
)

print("✓ Model training completed!")
# Out:
# Creating and training GTM model...
#
# Epoch   5	Mean Training Loss:1.9111361
#
#
# Epoch   5	Mean Validation Loss:3.1266251
#
#
# Epoch  10	Mean Training Loss:1.8918685
#
#
# Epoch  10	Mean Validation Loss:2.7556267
#
#
# Epoch  15	Mean Training Loss:1.8781118
#
#
# Epoch  15	Mean Validation Loss:2.2610997
#
#
# Epoch  20	Mean Training Loss:1.8724857
#
#
# Epoch  20	Mean Validation Loss:2.2903603
#
#
# Stopping at Epoch 20. Reverting to Epoch 15
# ✓ Model training completed!

# %% [markdown]
# ## Generate Samples with Different Color Covariates
#
# This is the main demonstration of the new `generate_samples` method!

# %%
# Test the new generate_samples method
print("Testing generate_samples method with different color covariates...")

# Get covariate structure from corpus
print(f"Content covariate names: {corpus.content_colnames}")
print(f"Content covariate shape: {corpus.M_content_covariates.shape}")

# Create different color covariate configurations
n_gen_samples = 5

# Helper function to create color covariates
def create_color_covariates(color_name, n_samples):
    covariates = torch.zeros(n_samples, len(corpus.content_colnames))
    covariates[:, 0] = 1.0  # Intercept
    
    color_col_name = f'C(color_name)[T.{color_name}]'
    if color_col_name in corpus.content_colnames:
        color_idx = corpus.content_colnames.index(color_col_name)
        covariates[:, color_idx] = 1.0
    
    return covariates

# Generate samples for each color
color_configs = ['red', 'green', 'blue', 'yellow']
generated_results = {}

for color_name in color_configs:
    print(f"\nGenerating {color_name} samples...")
    
    try:
        # Create color-specific covariates
        content_cov = create_color_covariates(color_name, n_gen_samples)
        
        # Generate samples
        generated_samples = model.generate_samples(
            n_samples=n_gen_samples,
            content_covariates=content_cov,
            modality_keys=["visual_colored_mnist"],
            temperature=0.8,  # Slightly less random for clearer results
            seed=42 + hash(color_name) % 1000  # Different seed per color
        )
        
        generated_results[color_name] = generated_samples
        
        # Analyze generated images
        if "visual_colored_mnist" in generated_samples:
            images = generated_samples["visual_colored_mnist"]
            print(f"  Generated images shape: {images.shape}")
            
            if len(images.shape) == 4:  # [N, C, H, W]
                # Calculate average RGB values
                avg_rgb = images.mean(axis=(2, 3))  # Average over spatial dims
                mean_rgb = avg_rgb.mean(axis=0)  # Average over batch
                print(f"  Average RGB values: [{mean_rgb[0]:.3f}, {mean_rgb[1]:.3f}, {mean_rgb[2]:.3f}]")
                
                # Find dominant color channel
                dominant_channels = avg_rgb.argmax(axis=1)
                channel_names = ['Red', 'Green', 'Blue']
                dominant_colors = [channel_names[ch] for ch in dominant_channels]
                print(f"  Dominant color channels: {dominant_colors}")
        
        print(f"  ✓ {color_name.capitalize()} generation successful!")
        
    except Exception as e:
        print(f"  ✗ Error generating {color_name} samples: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Testing generate_samples method with different color covariates...
# Content covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']
# Content covariate shape: (25000, 4)
#
# Generating red samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.196, 0.055, 0.055]
#   Dominant color channels: ['Red', 'Red', 'Red', 'Red', 'Red']
#   ✓ Red generation successful!
#
# Generating green samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.051, 0.181, 0.052]
#   Dominant color channels: ['Green', 'Green', 'Green', 'Green', 'Green']
#   ✓ Green generation successful!
#
# Generating blue samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.061, 0.062, 0.225]
#   Dominant color channels: ['Blue', 'Blue', 'Blue', 'Blue', 'Blue']
#   ✓ Blue generation successful!
#
# Generating yellow samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.209, 0.203, 0.057]
#   Dominant color channels: ['Red', 'Red', 'Green', 'Red', 'Red']
#   ✓ Yellow generation successful!

# %% [markdown]
# ## Compare Generated Images Across Colors

# %%
# Compare generations across colors
print("\nComparing generated samples across colors...")

# Compare image RGB statistics
print("Image color analysis:")
color_stats = {}

for color_name, samples in generated_results.items():
    if "visual_colored_mnist" in samples:
        images = samples["visual_colored_mnist"]
        if len(images.shape) == 4:
            # Calculate color statistics
            mean_rgb = images.mean(axis=(0, 2, 3))  # Mean over batch and spatial
            std_rgb = images.std(axis=(0, 2, 3))   # Std over batch and spatial
            
            color_stats[color_name] = {
                'mean_rgb': mean_rgb,
                'std_rgb': std_rgb
            }
            
            print(f"  {color_name.capitalize()}: RGB mean=[{mean_rgb[0]:.3f}, {mean_rgb[1]:.3f}, {mean_rgb[2]:.3f}], "
                  f"std=[{std_rgb[0]:.3f}, {std_rgb[1]:.3f}, {std_rgb[2]:.3f}]")

# Create a summary DataFrame
if color_stats:
    summary_data = []
    for color, stats in color_stats.items():
        summary_data.append({
            'color': color,
            'red_mean': stats['mean_rgb'][0].item(),
            'green_mean': stats['mean_rgb'][1].item(),
            'blue_mean': stats['mean_rgb'][2].item(),
            'dominant_channel': ['red', 'green', 'blue'][stats['mean_rgb'].argmax()]
        })
    
    summary_df = pd.DataFrame(summary_data)
    print("\nGenerated Image Color Summary:")
    display(summary_df)
# Out:
# Comparing generated samples across colors...
# Image color analysis:
#   Red: RGB mean=[0.196, 0.055, 0.055], std=[0.153, 0.042, 0.042]
#   Green: RGB mean=[0.051, 0.181, 0.052], std=[0.046, 0.163, 0.049]
#   Blue: RGB mean=[0.061, 0.062, 0.225], std=[0.058, 0.060, 0.208]
#   Yellow: RGB mean=[0.209, 0.203, 0.057], std=[0.188, 0.186, 0.053]
#
# Generated Image Color Summary:
#     color  red_mean  green_mean  blue_mean dominant_channel
# 0     red  0.195638    0.054882   0.055041              red
# 1   green  0.050545    0.180576   0.052356            green
# 2    blue  0.060744    0.062451   0.225483             blue
# 3  yellow  0.208913    0.202883   0.057394              red

# %% [markdown]
# ## Visualize Generated Samples

# %%
# Visualize generated samples
if generated_results and MATPLOTLIB_AVAILABLE:
    print("Visualizing generated samples...")
    
    # Create visualization of generated samples
    fig, axes = plt.subplots(len(generated_results), min(n_gen_samples, 4), 
                           figsize=(12, 3 * len(generated_results)))
    
    if len(generated_results) == 1:
        axes = axes.reshape(1, -1)
    
    for row, (color_name, samples) in enumerate(generated_results.items()):
        if "visual_colored_mnist" in samples:
            images = samples["visual_colored_mnist"]
            
            for col in range(min(images.shape[0], 4)):
                img = images[col]
                
                # Convert from tensor format [C, H, W] to [H, W, C] for matplotlib
                if len(img.shape) == 3:
                    img_display = img.transpose(1, 2, 0)
                else:
                    img_display = img
                
                # Clip values to [0, 1] range
                img_display = np.clip(img_display, 0, 1)
                
                axes[row, col].imshow(img_display)
                axes[row, col].set_title(f"Generated {color_name}")
                axes[row, col].axis('off')
    
    plt.tight_layout()
    plt.suptitle('Generated Colored MNIST Samples by Color Covariate', y=1.02, fontsize=16)
    plt.show()
    
    print("✓ Generated samples visualization completed!")
else:
    print("Visualization skipped (matplotlib not available or no samples generated)")
# Out:
# Visualizing generated samples...
# ✓ Generated samples visualization completed!
