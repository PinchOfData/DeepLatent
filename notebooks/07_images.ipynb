# %% [markdown]
# # DeepLatent with Colored MNIST
#
# This notebook demonstrates:
# 1. **Colored MNIST Dataset Creation** - MNIST digits with color shifts as covariates
# 2. **FiLM Conditioning** - Images conditioned on color covariates
# 3. **Content Generation** - Generate new samples with different covariate configurations

# %% [markdown]
# ## Setup and Imports

# %%
import torch.nn.functional as F
import torch
import numpy as np
import pandas as pd
from PIL import Image
import os
import tempfile
from sklearn.feature_extraction.text import CountVectorizer
from typing import List, Tuple

# Handle imports gracefully
try:
    import matplotlib.pyplot as plt
    MATPLOTLIB_AVAILABLE = True
    print("✓ Matplotlib available")
except ImportError:
    print("⚠ Warning: matplotlib not available")
    MATPLOTLIB_AVAILABLE = False

try:
    import torchvision
    import torchvision.transforms as transforms
    from torchvision.datasets import MNIST
    TORCHVISION_AVAILABLE = True
    print("✓ Torchvision available")
except Exception as e:
    print(f"⚠ Warning: torchvision not available, will use synthetic data")
    TORCHVISION_AVAILABLE = False

# Import DeepLatent classes
from deeplatent import Corpus, DeepLatent

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {'CUDA' if torch.cuda.is_available() else 'CPU'}")
# Out:
# ✓ Matplotlib available
# ✓ Torchvision available
# PyTorch version: 2.8.0+cu128
# Device: CUDA

# %% [markdown]
# ## Define Transform Classes (Fallback for Missing Torchvision)

# %%
if not TORCHVISION_AVAILABLE:
    # Define minimal transforms class for fallback
    class transforms:
        @staticmethod
        class Compose:
            def __init__(self, transforms_list):
                self.transforms = transforms_list
            def __call__(self, x):
                for t in self.transforms:
                    x = t(x)
                return x
        
        @staticmethod
        class ToTensor:
            def __call__(self, pic):
                if isinstance(pic, np.ndarray):
                    return torch.from_numpy(pic.transpose((2, 0, 1))).float() / 255.0
                elif isinstance(pic, Image.Image):
                    return torch.from_numpy(np.array(pic)).float().unsqueeze(0) / 255.0
                return pic
        
        @staticmethod
        class ToPILImage:
            def __call__(self, tensor):
                if tensor.dim() == 3:
                    np_array = (tensor.permute(1, 2, 0).numpy() * 255).astype(np.uint8)
                    return Image.fromarray(np_array)
                else:
                    np_array = (tensor.numpy() * 255).astype(np.uint8)
                    return Image.fromarray(np_array, mode='L')
        
        @staticmethod
        class Resize:
            def __init__(self, size):
                self.size = size if isinstance(size, tuple) else (size, size)
            def __call__(self, img):
                return img.resize(self.size)
    
    print("✓ Fallback transforms defined")

# %% [markdown]
# ## Configuration

# %%
# Configuration parameters
CONFIG = {
    'n_samples': 50000,  # Number of MNIST samples to generate
    'colors': ['red', 'green', 'blue', 'yellow'],
    'image_size': (28, 28)
}

print(f"Configuration: {CONFIG}")
# Out:
# Configuration: {'n_samples': 50000, 'colors': ['red', 'green', 'blue', 'yellow'], 'image_size': (28, 28)}

# %% [markdown]
# ## Colored MNIST Dataset Creation

# %%
class ColoredMNISTDataset:
    """Create MNIST dataset with color shifts and text descriptions."""
    
    def __init__(self, n_samples: int = 1000, colors: List[str] = None):
        self.n_samples = n_samples
        self.colors = colors or ['red', 'green', 'blue', 'yellow']
        self.color_values = {
            'red': [1.0, 0.3, 0.3],
            'green': [0.3, 1.0, 0.3], 
            'blue': [0.3, 0.3, 1.0],
            'yellow': [1.0, 1.0, 0.3],
            'purple': [0.8, 0.3, 0.8],
            'orange': [1.0, 0.6, 0.2],
            'cyan': [0.3, 0.8, 0.8],
            'pink': [1.0, 0.6, 0.8]
        }
        
        # Create temporary directory for images
        self.temp_dir = tempfile.mkdtemp()
        print(f"Creating colored MNIST images in: {self.temp_dir}")
        
        # Generate dataset
        self.data = self._generate_colored_mnist()
    
    def _generate_colored_mnist(self) -> pd.DataFrame:
        """Generate colored MNIST images with text descriptions."""
        
        if TORCHVISION_AVAILABLE:
            # Load MNIST dataset using torchvision
            transform = transforms.Compose([transforms.ToTensor()])
            mnist_dataset = MNIST(root='./data', train=True, download=True, transform=transform)
        else:
            # Fallback: create synthetic MNIST-like data
            print("Using synthetic MNIST-like data (torchvision not available)")
            mnist_dataset = self._create_synthetic_mnist()
        
        data_records = []
        digit_names = ['zero', 'one', 'two', 'three', 'four', 
                      'five', 'six', 'seven', 'eight', 'nine']
        
        np.random.seed(42)  # For reproducibility
        torch.manual_seed(42)
        
        for i in range(self.n_samples):
            # Sample random MNIST image
            idx = np.random.randint(0, len(mnist_dataset))
            
            if TORCHVISION_AVAILABLE:
                mnist_img, digit_label = mnist_dataset[idx]
            else:
                mnist_img, digit_label = mnist_dataset[idx]
            
            # Sample random color
            color_name = np.random.choice(self.colors)
            color_rgb = self.color_values[color_name]
            
            # Convert grayscale MNIST to colored RGB
            colored_img = self._apply_color_to_mnist(mnist_img, color_rgb)
            
            # Save colored image
            img_filename = f"mnist_{i:04d}_digit{digit_label}_color{color_name}.png"
            img_path = os.path.join(self.temp_dir, img_filename)
            
            # Convert tensor to PIL and save
            img_pil = transforms.ToPILImage()(colored_img)
            img_pil.save(img_path)
            
            # Create text description
            digit_name = digit_names[digit_label]
            text_description = f"A {color_name} colored number {digit_name}"
            
            # Add some variation to text
            variations = [
                f"The digit {digit_name} in {color_name} color",
                f"Number {digit_name} colored {color_name}",
                f"A {color_name} {digit_name}",
                f"{color_name.capitalize()} digit {digit_name}"
            ]
            if np.random.random() > 0.5:
                text_description = np.random.choice(variations)
            
            data_records.append({
                'sample_id': i,
                'image_path': img_path,
                'digit_label': digit_label,
                'digit_name': digit_name,
                'color_name': color_name,
                'color_r': color_rgb[0],
                'color_g': color_rgb[1], 
                'color_b': color_rgb[2],
                'text_description': text_description,
                'is_even': digit_label % 2 == 0,
                'digit_category': 'low' if digit_label < 5 else 'high'
            })
            
            if (i + 1) % 100 == 0:
                print(f"Generated {i + 1}/{self.n_samples} samples")
        
        df = pd.DataFrame(data_records)
        print(f"✓ Created dataset with {len(df)} samples")
        
        return df
    
    def _create_synthetic_mnist(self):
        """Create synthetic MNIST-like dataset when torchvision is not available."""
        print("Creating synthetic digit-like images...")
        
        class SyntheticMNIST:
            def __init__(self, n_samples=1000):
                self.data = []
                np.random.seed(42)
                
                for i in range(n_samples):
                    digit_label = i % 10
                    img = self._create_digit_pattern(digit_label)
                    tensor = torch.from_numpy(img).float().unsqueeze(0)
                    self.data.append((tensor, digit_label))
            
            def _create_digit_pattern(self, digit):
                """Create simple patterns that roughly resemble digits."""
                img = np.zeros((28, 28), dtype=np.float32)
                
                if digit == 0:  # Circle
                    center = (14, 14)
                    for i in range(28):
                        for j in range(28):
                            dist = np.sqrt((i - center[0])**2 + (j - center[1])**2)
                            if 8 <= dist <= 12:
                                img[i, j] = 1.0
                elif digit == 1:  # Vertical line
                    img[4:24, 12:16] = 1.0
                # Add more digit patterns...
                
                # Add some noise for realism
                noise = np.random.normal(0, 0.05, (28, 28))
                img = np.clip(img + noise, 0, 1)
                
                return img
            
            def __len__(self):
                return len(self.data)
            
            def __getitem__(self, idx):
                return self.data[idx]
        
        return SyntheticMNIST(1000)
    
    def _apply_color_to_mnist(self, mnist_tensor: torch.Tensor, color_rgb: List[float]) -> torch.Tensor:
        """Apply color tint to grayscale MNIST image."""
        # Convert grayscale to RGB by repeating channel
        rgb_img = mnist_tensor.repeat(3, 1, 1)  # [3, H, W]
        
        # Apply color tint by element-wise multiplication
        for channel in range(3):
            rgb_img[channel] *= color_rgb[channel]
        
        # Add some background color variation
        background_intensity = 0.1
        for channel in range(3):
            background = torch.ones_like(rgb_img[channel]) * background_intensity * color_rgb[channel]
            rgb_img[channel] = torch.where(rgb_img[channel] < 0.1, background, rgb_img[channel])
        
        return rgb_img
    
    def cleanup(self):
        """Remove temporary image files."""
        import shutil
        shutil.rmtree(self.temp_dir)
        print(f"Cleaned up temporary directory: {self.temp_dir}")

print("✓ ColoredMNISTDataset class defined")
# Out:
# ✓ ColoredMNISTDataset class defined

# %% [markdown]
# ## Image Transform Function

# %%
def mnist_image_transform_function(image_paths: List[str]) -> torch.Tensor:
    """Transform function for MNIST images."""
    transform = transforms.Compose([
        transforms.Resize(CONFIG['image_size']),
        transforms.ToTensor(),
    ])
    
    processed_images = []
    for path in image_paths:
        try:
            img = Image.open(path).convert('RGB')
            tensor = transform(img)
            processed_images.append(tensor)
        except Exception as e:
            print(f"Error loading {path}: {e}")
            # Fallback: zero tensor
            processed_images.append(torch.zeros(3, *CONFIG['image_size']))
    
    # For single image (lazy loading), return the tensor directly
    if len(processed_images) == 1:
        return processed_images[0]
    
    # For batch processing, return stacked tensor
    return torch.stack(processed_images)

print("✓ Image transform function defined")
# Out:
# ✓ Image transform function defined

# %% [markdown]
# ## Generate Dataset

# %%
# Generate colored MNIST dataset
print("Generating colored MNIST dataset...")
dataset = ColoredMNISTDataset(n_samples=CONFIG['n_samples'], colors=CONFIG['colors'])
df = dataset.data

# Display dataset statistics
print(f"\nDataset Statistics:")
print(f"- Total samples: {len(df)}")
print(f"- Colors distribution: {df['color_name'].value_counts().to_dict()}")
print(f"- Digits distribution: {df['digit_label'].value_counts().to_dict()}")

# Show some sample descriptions
print(f"\nSample text descriptions:")
for i in range(5):
    print(f"  {i+1}. {df.iloc[i]['text_description']}")

# Display first few rows
df.head()
# Out:
# Generating colored MNIST dataset...
# Creating colored MNIST images in: /tmp/tmpe03057fs
# Generated 100/50000 samples
# Generated 200/50000 samples
# Generated 300/50000 samples
# Generated 400/50000 samples
# Generated 500/50000 samples
# Generated 600/50000 samples
# Generated 700/50000 samples
# Generated 800/50000 samples
# Generated 900/50000 samples
# Generated 1000/50000 samples
# Generated 1100/50000 samples
# Generated 1200/50000 samples
# Generated 1300/50000 samples
# Generated 1400/50000 samples
# Generated 1500/50000 samples
# Generated 1600/50000 samples
# Generated 1700/50000 samples
# Generated 1800/50000 samples
# Generated 1900/50000 samples
# Generated 2000/50000 samples
# Generated 2100/50000 samples
# Generated 2200/50000 samples
# Generated 2300/50000 samples
# Generated 2400/50000 samples
# Generated 2500/50000 samples
# Generated 2600/50000 samples
# Generated 2700/50000 samples
# Generated 2800/50000 samples
# Generated 2900/50000 samples
# Generated 3000/50000 samples
# Generated 3100/50000 samples
# Generated 3200/50000 samples
# Generated 3300/50000 samples
# Generated 3400/50000 samples
# Generated 3500/50000 samples
# Generated 3600/50000 samples
# Generated 3700/50000 samples
# Generated 3800/50000 samples
# Generated 3900/50000 samples
# Generated 4000/50000 samples
# Generated 4100/50000 samples
# Generated 4200/50000 samples
# Generated 4300/50000 samples
# Generated 4400/50000 samples
# Generated 4500/50000 samples
# Generated 4600/50000 samples
# Generated 4700/50000 samples
# Generated 4800/50000 samples
# Generated 4900/50000 samples
# Generated 5000/50000 samples
# Generated 5100/50000 samples
# Generated 5200/50000 samples
# Generated 5300/50000 samples
# Generated 5400/50000 samples
# Generated 5500/50000 samples
# Generated 5600/50000 samples
# Generated 5700/50000 samples
# Generated 5800/50000 samples
# Generated 5900/50000 samples
# Generated 6000/50000 samples
# Generated 6100/50000 samples
# Generated 6200/50000 samples
# Generated 6300/50000 samples
# Generated 6400/50000 samples
# Generated 6500/50000 samples
# Generated 6600/50000 samples
# Generated 6700/50000 samples
# Generated 6800/50000 samples
# Generated 6900/50000 samples
# Generated 7000/50000 samples
# Generated 7100/50000 samples
# Generated 7200/50000 samples
# Generated 7300/50000 samples
# Generated 7400/50000 samples
# Generated 7500/50000 samples
# Generated 7600/50000 samples
# Generated 7700/50000 samples
# Generated 7800/50000 samples
# Generated 7900/50000 samples
# Generated 8000/50000 samples
# Generated 8100/50000 samples
# Generated 8200/50000 samples
# Generated 8300/50000 samples
# Generated 8400/50000 samples
# Generated 8500/50000 samples
# Generated 8600/50000 samples
# Generated 8700/50000 samples
# Generated 8800/50000 samples
# Generated 8900/50000 samples
# Generated 9000/50000 samples
# Generated 9100/50000 samples
# Generated 9200/50000 samples
# Generated 9300/50000 samples
# Generated 9400/50000 samples
# Generated 9500/50000 samples
# Generated 9600/50000 samples
# Generated 9700/50000 samples
# Generated 9800/50000 samples
# Generated 9900/50000 samples
# Generated 10000/50000 samples
# Generated 10100/50000 samples
# Generated 10200/50000 samples
# Generated 10300/50000 samples
# Generated 10400/50000 samples
# Generated 10500/50000 samples
# Generated 10600/50000 samples
# Generated 10700/50000 samples
# Generated 10800/50000 samples
# Generated 10900/50000 samples
# Generated 11000/50000 samples
# Generated 11100/50000 samples
# Generated 11200/50000 samples
# Generated 11300/50000 samples
# Generated 11400/50000 samples
# Generated 11500/50000 samples
# Generated 11600/50000 samples
# Generated 11700/50000 samples
# Generated 11800/50000 samples
# Generated 11900/50000 samples
# Generated 12000/50000 samples
# Generated 12100/50000 samples
# Generated 12200/50000 samples
# Generated 12300/50000 samples
# Generated 12400/50000 samples
# Generated 12500/50000 samples
# Generated 12600/50000 samples
# Generated 12700/50000 samples
# Generated 12800/50000 samples
# Generated 12900/50000 samples
# Generated 13000/50000 samples
# Generated 13100/50000 samples
# Generated 13200/50000 samples
# Generated 13300/50000 samples
# Generated 13400/50000 samples
# Generated 13500/50000 samples
# Generated 13600/50000 samples
# Generated 13700/50000 samples
# Generated 13800/50000 samples
# Generated 13900/50000 samples
# Generated 14000/50000 samples
# Generated 14100/50000 samples
# Generated 14200/50000 samples
# Generated 14300/50000 samples
# Generated 14400/50000 samples
# Generated 14500/50000 samples
# Generated 14600/50000 samples
# Generated 14700/50000 samples
# Generated 14800/50000 samples
# Generated 14900/50000 samples
# Generated 15000/50000 samples
# Generated 15100/50000 samples
# Generated 15200/50000 samples
# Generated 15300/50000 samples
# Generated 15400/50000 samples
# Generated 15500/50000 samples
# Generated 15600/50000 samples
# Generated 15700/50000 samples
# Generated 15800/50000 samples
# Generated 15900/50000 samples
# Generated 16000/50000 samples
# Generated 16100/50000 samples
# Generated 16200/50000 samples
# Generated 16300/50000 samples
# Generated 16400/50000 samples
# Generated 16500/50000 samples
# Generated 16600/50000 samples
# Generated 16700/50000 samples
# Generated 16800/50000 samples
# Generated 16900/50000 samples
# Generated 17000/50000 samples
# Generated 17100/50000 samples
# Generated 17200/50000 samples
# Generated 17300/50000 samples
# Generated 17400/50000 samples
# Generated 17500/50000 samples
# Generated 17600/50000 samples
# Generated 17700/50000 samples
# Generated 17800/50000 samples
# Generated 17900/50000 samples
# Generated 18000/50000 samples
# Generated 18100/50000 samples
# Generated 18200/50000 samples
# Generated 18300/50000 samples
# Generated 18400/50000 samples
# Generated 18500/50000 samples
# Generated 18600/50000 samples
# Generated 18700/50000 samples
# Generated 18800/50000 samples
# Generated 18900/50000 samples
# Generated 19000/50000 samples
# Generated 19100/50000 samples
# Generated 19200/50000 samples
# Generated 19300/50000 samples
# Generated 19400/50000 samples
# Generated 19500/50000 samples
# Generated 19600/50000 samples
# Generated 19700/50000 samples
# Generated 19800/50000 samples
# Generated 19900/50000 samples
# Generated 20000/50000 samples
# Generated 20100/50000 samples
# Generated 20200/50000 samples
# Generated 20300/50000 samples
# Generated 20400/50000 samples
# Generated 20500/50000 samples
# Generated 20600/50000 samples
# Generated 20700/50000 samples
# Generated 20800/50000 samples
# Generated 20900/50000 samples
# Generated 21000/50000 samples
# Generated 21100/50000 samples
# Generated 21200/50000 samples
# Generated 21300/50000 samples
# Generated 21400/50000 samples
# Generated 21500/50000 samples
# Generated 21600/50000 samples
# Generated 21700/50000 samples
# Generated 21800/50000 samples
# Generated 21900/50000 samples
# Generated 22000/50000 samples
# Generated 22100/50000 samples
# Generated 22200/50000 samples
# Generated 22300/50000 samples
# Generated 22400/50000 samples
# Generated 22500/50000 samples
# Generated 22600/50000 samples
# Generated 22700/50000 samples
# Generated 22800/50000 samples
# Generated 22900/50000 samples
# Generated 23000/50000 samples
# Generated 23100/50000 samples
# Generated 23200/50000 samples
# Generated 23300/50000 samples
# Generated 23400/50000 samples
# Generated 23500/50000 samples
# Generated 23600/50000 samples
# Generated 23700/50000 samples
# Generated 23800/50000 samples
# Generated 23900/50000 samples
# Generated 24000/50000 samples
# Generated 24100/50000 samples
# Generated 24200/50000 samples
# Generated 24300/50000 samples
# Generated 24400/50000 samples
# Generated 24500/50000 samples
# Generated 24600/50000 samples
# Generated 24700/50000 samples
# Generated 24800/50000 samples
# Generated 24900/50000 samples
# Generated 25000/50000 samples
# Generated 25100/50000 samples
# Generated 25200/50000 samples
# Generated 25300/50000 samples
# Generated 25400/50000 samples
# Generated 25500/50000 samples
# Generated 25600/50000 samples
# Generated 25700/50000 samples
# Generated 25800/50000 samples
# Generated 25900/50000 samples
# Generated 26000/50000 samples
# Generated 26100/50000 samples
# Generated 26200/50000 samples
# Generated 26300/50000 samples
# Generated 26400/50000 samples
# Generated 26500/50000 samples
# Generated 26600/50000 samples
# Generated 26700/50000 samples
# Generated 26800/50000 samples
# Generated 26900/50000 samples
# Generated 27000/50000 samples
# Generated 27100/50000 samples
# Generated 27200/50000 samples
# Generated 27300/50000 samples
# Generated 27400/50000 samples
# Generated 27500/50000 samples
# Generated 27600/50000 samples
# Generated 27700/50000 samples
# Generated 27800/50000 samples
# Generated 27900/50000 samples
# Generated 28000/50000 samples
# Generated 28100/50000 samples
# Generated 28200/50000 samples
# Generated 28300/50000 samples
# Generated 28400/50000 samples
# Generated 28500/50000 samples
# Generated 28600/50000 samples
# Generated 28700/50000 samples
# Generated 28800/50000 samples
# Generated 28900/50000 samples
# Generated 29000/50000 samples
# Generated 29100/50000 samples
# Generated 29200/50000 samples
# Generated 29300/50000 samples
# Generated 29400/50000 samples
# Generated 29500/50000 samples
# Generated 29600/50000 samples
# Generated 29700/50000 samples
# Generated 29800/50000 samples
# Generated 29900/50000 samples
# Generated 30000/50000 samples
# Generated 30100/50000 samples
# Generated 30200/50000 samples
# Generated 30300/50000 samples
# Generated 30400/50000 samples
# Generated 30500/50000 samples
# Generated 30600/50000 samples
# Generated 30700/50000 samples
# Generated 30800/50000 samples
# Generated 30900/50000 samples
# Generated 31000/50000 samples
# Generated 31100/50000 samples
# Generated 31200/50000 samples
# Generated 31300/50000 samples
# Generated 31400/50000 samples
# Generated 31500/50000 samples
# Generated 31600/50000 samples
# Generated 31700/50000 samples
# Generated 31800/50000 samples
# Generated 31900/50000 samples
# Generated 32000/50000 samples
# Generated 32100/50000 samples
# Generated 32200/50000 samples
# Generated 32300/50000 samples
# Generated 32400/50000 samples
# Generated 32500/50000 samples
# Generated 32600/50000 samples
# Generated 32700/50000 samples
# Generated 32800/50000 samples
# Generated 32900/50000 samples
# Generated 33000/50000 samples
# Generated 33100/50000 samples
# Generated 33200/50000 samples
# Generated 33300/50000 samples
# Generated 33400/50000 samples
# Generated 33500/50000 samples
# Generated 33600/50000 samples
# Generated 33700/50000 samples
# Generated 33800/50000 samples
# Generated 33900/50000 samples
# Generated 34000/50000 samples
# Generated 34100/50000 samples
# Generated 34200/50000 samples
# Generated 34300/50000 samples
# Generated 34400/50000 samples
# Generated 34500/50000 samples
# Generated 34600/50000 samples
# Generated 34700/50000 samples
# Generated 34800/50000 samples
# Generated 34900/50000 samples
# Generated 35000/50000 samples
# Generated 35100/50000 samples
# Generated 35200/50000 samples
# Generated 35300/50000 samples
# Generated 35400/50000 samples
# Generated 35500/50000 samples
# Generated 35600/50000 samples
# Generated 35700/50000 samples
# Generated 35800/50000 samples
# Generated 35900/50000 samples
# Generated 36000/50000 samples
# Generated 36100/50000 samples
# Generated 36200/50000 samples
# Generated 36300/50000 samples
# Generated 36400/50000 samples
# Generated 36500/50000 samples
# Generated 36600/50000 samples
# Generated 36700/50000 samples
# Generated 36800/50000 samples
# Generated 36900/50000 samples
# Generated 37000/50000 samples
# Generated 37100/50000 samples
# Generated 37200/50000 samples
# Generated 37300/50000 samples
# Generated 37400/50000 samples
# Generated 37500/50000 samples
# Generated 37600/50000 samples
# Generated 37700/50000 samples
# Generated 37800/50000 samples
# Generated 37900/50000 samples
# Generated 38000/50000 samples
# Generated 38100/50000 samples
# Generated 38200/50000 samples
# Generated 38300/50000 samples
# Generated 38400/50000 samples
# Generated 38500/50000 samples
# Generated 38600/50000 samples
# Generated 38700/50000 samples
# Generated 38800/50000 samples
# Generated 38900/50000 samples
# Generated 39000/50000 samples
# Generated 39100/50000 samples
# Generated 39200/50000 samples
# Generated 39300/50000 samples
# Generated 39400/50000 samples
# Generated 39500/50000 samples
# Generated 39600/50000 samples
# Generated 39700/50000 samples
# Generated 39800/50000 samples
# Generated 39900/50000 samples
# Generated 40000/50000 samples
# Generated 40100/50000 samples
# Generated 40200/50000 samples
# Generated 40300/50000 samples
# Generated 40400/50000 samples
# Generated 40500/50000 samples
# Generated 40600/50000 samples
# Generated 40700/50000 samples
# Generated 40800/50000 samples
# Generated 40900/50000 samples
# Generated 41000/50000 samples
# Generated 41100/50000 samples
# Generated 41200/50000 samples
# Generated 41300/50000 samples
# Generated 41400/50000 samples
# Generated 41500/50000 samples
# Generated 41600/50000 samples
# Generated 41700/50000 samples
# Generated 41800/50000 samples
# Generated 41900/50000 samples
# Generated 42000/50000 samples
# Generated 42100/50000 samples
# Generated 42200/50000 samples
# Generated 42300/50000 samples
# Generated 42400/50000 samples
# Generated 42500/50000 samples
# Generated 42600/50000 samples
# Generated 42700/50000 samples
# Generated 42800/50000 samples
# Generated 42900/50000 samples
# Generated 43000/50000 samples
# Generated 43100/50000 samples
# Generated 43200/50000 samples
# Generated 43300/50000 samples
# Generated 43400/50000 samples
# Generated 43500/50000 samples
# Generated 43600/50000 samples
# Generated 43700/50000 samples
# Generated 43800/50000 samples
# Generated 43900/50000 samples
# Generated 44000/50000 samples
# Generated 44100/50000 samples
# Generated 44200/50000 samples
# Generated 44300/50000 samples
# Generated 44400/50000 samples
# Generated 44500/50000 samples
# Generated 44600/50000 samples
# Generated 44700/50000 samples
# Generated 44800/50000 samples
# Generated 44900/50000 samples
# Generated 45000/50000 samples
# Generated 45100/50000 samples
# Generated 45200/50000 samples
# Generated 45300/50000 samples
# Generated 45400/50000 samples
# Generated 45500/50000 samples
# Generated 45600/50000 samples
# Generated 45700/50000 samples
# Generated 45800/50000 samples
# Generated 45900/50000 samples
# Generated 46000/50000 samples
# Generated 46100/50000 samples
# Generated 46200/50000 samples
# Generated 46300/50000 samples
# Generated 46400/50000 samples
# Generated 46500/50000 samples
# Generated 46600/50000 samples
# Generated 46700/50000 samples
# Generated 46800/50000 samples
# Generated 46900/50000 samples
# Generated 47000/50000 samples
# Generated 47100/50000 samples
# Generated 47200/50000 samples
# Generated 47300/50000 samples
# Generated 47400/50000 samples
# Generated 47500/50000 samples
# Generated 47600/50000 samples
# Generated 47700/50000 samples
# Generated 47800/50000 samples
# Generated 47900/50000 samples
# Generated 48000/50000 samples
# Generated 48100/50000 samples
# Generated 48200/50000 samples
# Generated 48300/50000 samples
# Generated 48400/50000 samples
# Generated 48500/50000 samples
# Generated 48600/50000 samples
# Generated 48700/50000 samples
# Generated 48800/50000 samples
# Generated 48900/50000 samples
# Generated 49000/50000 samples
# Generated 49100/50000 samples
# Generated 49200/50000 samples
# Generated 49300/50000 samples
# Generated 49400/50000 samples
# Generated 49500/50000 samples
# Generated 49600/50000 samples
# Generated 49700/50000 samples
# Generated 49800/50000 samples
# Generated 49900/50000 samples
# Generated 50000/50000 samples
# ✓ Created dataset with 50000 samples
#
# Dataset Statistics:
# - Total samples: 50000
# - Colors distribution: {np.str_('green'): 12559, np.str_('yellow'): 12534, np.str_('blue'): 12500, np.str_('red'): 12407}
# - Digits distribution: {1: 5658, 7: 5214, 3: 5055, 6: 5046, 9: 4984, 0: 4969, 2: 4961, 8: 4879, 4: 4849, 5: 4385}
#
# Sample text descriptions:
#   1. A yellow four
#   2. Number three colored red
#   3. A blue colored number four
#   4. Red digit six
#   5. A green colored number one
#    sample_id                                         image_path  digit_label  \
# 0          0  /tmp/tmpe03057fs/mnist_0000_digit4_coloryellow...            4
# 1          1    /tmp/tmpe03057fs/mnist_0001_digit3_colorred.png            3
# 2          2   /tmp/tmpe03057fs/mnist_0002_digit4_colorblue.png            4
# 3          3    /tmp/tmpe03057fs/mnist_0003_digit6_colorred.png            6
# 4          4  /tmp/tmpe03057fs/mnist_0004_digit1_colorgreen.png            1
#
#   digit_name color_name  color_r  color_g  color_b  \
# 0       four     yellow      1.0      1.0      0.3
# 1      three        red      1.0      0.3      0.3
# 2       four       blue      0.3      0.3      1.0
# 3        six        red      1.0      0.3      0.3
# 4        one      green      0.3      1.0      0.3
#
#              text_description  is_even digit_category
# 0               A yellow four     True            low
# 1    Number three colored red    False            low
# 2  A blue colored number four     True            low
# 3               Red digit six     True           high
# 4  A green colored number one    False            low

# %% [markdown]
# ## Visualize Sample Images

# %%
if MATPLOTLIB_AVAILABLE:
    # Visualize some colored MNIST samples
    fig, axes = plt.subplots(2, 4, figsize=(12, 6))
    axes = axes.flatten()
    
    for i in range(8):
        sample = df.iloc[i]
        img = Image.open(sample['image_path'])
        
        axes[i].imshow(img)
        axes[i].set_title(f"Digit {sample['digit_label']} ({sample['color_name']})")
        axes[i].axis('off')
    
    plt.tight_layout()
    plt.title('Sample Colored MNIST Images', y=1.02, fontsize=16)
    plt.show()
else:
    print("Matplotlib not available - skipping visualization")

# %% [markdown]
# ## Create Multimodal Corpus

# %%
# Create corpus with both images and text
print("Creating multimodal corpus...")

modalities = {
    "text": {
        "views": {
            "bow": {
                "type": "bow",
                "column": "text_description",
                "vectorizer": CountVectorizer()
            }
        }
    },
    "visual": {
        "views": {
            "colored_mnist": {
                "type": "image",
                "column": "image_path",
                "transform_fn": mnist_image_transform_function
            }
        }
    }
}

corpus = Corpus(
    df,
    modalities=modalities,
    prevalence="~ C(color_name)",
    content="~ C(color_name)"  
)

train_corpus = Corpus(
    df,
    modalities=modalities,
    prevalence="~ C(color_name)",
    content="~ C(color_name)"  
)

print(f"✓ Corpus created with {len(corpus)} samples")
print(f"Prevalence covariates shape: {corpus.M_prevalence_covariates.shape}")
print(f"Content covariates shape: {corpus.M_content_covariates.shape}")
print(f"Prevalence covariate names: {corpus.prevalence_colnames}")
print(f"Content covariate names: {corpus.content_colnames}")
# Out:
# Creating multimodal corpus...
# ✓ Corpus created with 50000 samples
# Prevalence covariates shape: (50000, 4)
# Content covariates shape: (50000, 4)
# Prevalence covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']
# Content covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']

# %% [markdown]
# ## Configure Model Architecture

# %%
# Configure model architecture
print("Configuring model architecture...")

encoder_args = {
    "visual_colored_mnist": {
        "input_channels": 3,
        "hidden_dims": [32,64,128,256],      
        "fc_hidden_dims": [256],          
        "activation": "relu",
        "dropout": 0.1,
        "use_batch_norm": True,
        "input_size": CONFIG['image_size']
    }
}

decoder_args = {
    "visual_colored_mnist": {
        "output_channels": 3,
        "hidden_dims": [256,128,64,32],      
        "output_size": CONFIG['image_size'],
        "fc_hidden_dims": [256],
        "activation": "relu",
        "use_batch_norm": True,
        "dropout": 0.1
    }
}

print(f"✓ Architecture configured")
print(f"Encoder args: {encoder_args}")
print(f"Decoder args: {decoder_args}")
# Out:
# Configuring model architecture...
# ✓ Architecture configured
# Encoder args: {'visual_colored_mnist': {'input_channels': 3, 'hidden_dims': [32, 64, 128, 256], 'fc_hidden_dims': [256], 'activation': 'relu', 'dropout': 0.1, 'use_batch_norm': True, 'input_size': (28, 28)}}
# Decoder args: {'visual_colored_mnist': {'output_channels': 3, 'hidden_dims': [256, 128, 64, 32], 'output_size': (28, 28), 'fc_hidden_dims': [256], 'activation': 'relu', 'use_batch_norm': True, 'dropout': 0.1}}

# %% [markdown]
# ## Train Multimodal Model

# %%
# Create and train the model
print("Creating and training GTM model...")

model = DeepLatent(
    train_data=train_corpus,
    n_factors=10,
    ae_type="wae",
    vi_type="iaf",
    latent_factor_prior='gaussian',
    update_prior=False,
    encoder_args=encoder_args,
    decoder_args=decoder_args,
    fusion="corrected_poe",
    num_steps=10000,
    batch_size=100,
    print_every_n_steps=1000,
    w_prior=0.01
)

print("✓ Model training completed!")
# Out:
# Creating and training GTM model...
# Step   1000	Mean Training Loss:0.0112361
# Rec Loss:0.0100338
# Divergence Loss:0.0012022
# Pred Loss:0.0000000
#
# Step   2000	Mean Training Loss:0.0096466
# Rec Loss:0.0084443
# Divergence Loss:0.0012023
# Pred Loss:0.0000000
#
# Step   3000	Mean Training Loss:0.0092853
# Rec Loss:0.0080993
# Divergence Loss:0.0011860
# Pred Loss:0.0000000
#
# Step   4000	Mean Training Loss:0.0093318
# Rec Loss:0.0081435
# Divergence Loss:0.0011883
# Pred Loss:0.0000000
#
# Step   5000	Mean Training Loss:0.0087824
# Rec Loss:0.0075747
# Divergence Loss:0.0012077
# Pred Loss:0.0000000
#
# Step   6000	Mean Training Loss:0.0086504
# Rec Loss:0.0074439
# Divergence Loss:0.0012065
# Pred Loss:0.0000000
#
# Step   7000	Mean Training Loss:0.0086565
# Rec Loss:0.0074673
# Divergence Loss:0.0011892
# Pred Loss:0.0000000
#
# Step   8000	Mean Training Loss:0.0078590
# Rec Loss:0.0066900
# Divergence Loss:0.0011690
# Pred Loss:0.0000000
#
# Step   9000	Mean Training Loss:0.0085708
# Rec Loss:0.0073731
# Divergence Loss:0.0011977
# Pred Loss:0.0000000
#
# Step  10000	Mean Training Loss:0.0077200
# Rec Loss:0.0065099
# Divergence Loss:0.0012101
# Pred Loss:0.0000000
#
# ✓ Model training completed!

# %%
#model.num_steps = model.steps+10000
#model.train(train_corpus)
# Out:
# Step  11000	Mean Training Loss:0.0085275
# Rec Loss:0.0073398
# Divergence Loss:0.0011877
# Pred Loss:0.0000000
#
# Step  12000	Mean Training Loss:0.0085102
# Rec Loss:0.0073164
# Divergence Loss:0.0011938
# Pred Loss:0.0000000
#
# Step  13000	Mean Training Loss:0.0079492
# Rec Loss:0.0067447
# Divergence Loss:0.0012045
# Pred Loss:0.0000000
#
# Step  14000	Mean Training Loss:0.0081148
# Rec Loss:0.0069145
# Divergence Loss:0.0012003
# Pred Loss:0.0000000
#
# Step  15000	Mean Training Loss:0.0082723
# Rec Loss:0.0070794
# Divergence Loss:0.0011928
# Pred Loss:0.0000000
#
# Step  16000	Mean Training Loss:0.0082489
# Rec Loss:0.0070376
# Divergence Loss:0.0012113
# Pred Loss:0.0000000
#
# Step  17000	Mean Training Loss:0.0077574
# Rec Loss:0.0065649
# Divergence Loss:0.0011925
# Pred Loss:0.0000000
#
# Step  18000	Mean Training Loss:0.0080219
# Rec Loss:0.0068473
# Divergence Loss:0.0011746
# Pred Loss:0.0000000
#
# Step  19000	Mean Training Loss:0.0074129
# Rec Loss:0.0062194
# Divergence Loss:0.0011935
# Pred Loss:0.0000000
#
# Step  20000	Mean Training Loss:0.0078964
# Rec Loss:0.0067208
# Divergence Loss:0.0011756
# Pred Loss:0.0000000

# %% [markdown]
# ## Generate Samples with Different Color Covariates
#
# This is the main demonstration of the new `generate_samples` method!

# %%
# Test the new generate_samples method
print("Testing generate_samples method with different color covariates...")

# Get covariate structure from corpus
print(f"Content covariate names: {corpus.content_colnames}")
print(f"Content covariate shape: {corpus.M_content_covariates.shape}")

# Create different color covariate configurations
n_gen_samples = 5

# Helper function to create color covariates
def create_color_covariates(color_name, n_samples):
    covariates = torch.zeros(n_samples, len(corpus.content_colnames))
    covariates[:, 0] = 1.0  # Intercept
    
    color_col_name = f'C(color_name)[T.{color_name}]'
    if color_col_name in corpus.content_colnames:
        color_idx = corpus.content_colnames.index(color_col_name)
        covariates[:, color_idx] = 1.0
    
    return covariates

# Generate samples for each color
color_configs = ['red', 'green', 'blue', 'yellow']
generated_results = {}

for color_name in color_configs:
    print(f"\nGenerating {color_name} samples...")
    
    try:
        # Create color-specific covariates
        content_cov = create_color_covariates(color_name, n_gen_samples)
        
        # Generate samples
        generated_samples = model.generate_samples(
            n_samples=n_gen_samples,
            content_covariates=content_cov,
            modality_keys=["visual_colored_mnist"],
            temperature=0.8,  # Slightly less random for clearer results
            seed=42 + hash(color_name) % 1000  # Different seed per color
        )
        
        generated_results[color_name] = generated_samples
        
        # Analyze generated images
        if "visual_colored_mnist" in generated_samples:
            images = generated_samples["visual_colored_mnist"]
            print(f"  Generated images shape: {images.shape}")
            
            if len(images.shape) == 4:  # [N, C, H, W]
                # Calculate average RGB values
                avg_rgb = images.mean(axis=(2, 3))  # Average over spatial dims
                mean_rgb = avg_rgb.mean(axis=0)  # Average over batch
                print(f"  Average RGB values: [{mean_rgb[0]:.3f}, {mean_rgb[1]:.3f}, {mean_rgb[2]:.3f}]")
                
                # Find dominant color channel
                dominant_channels = avg_rgb.argmax(axis=1)
                channel_names = ['Red', 'Green', 'Blue']
                dominant_colors = [channel_names[ch] for ch in dominant_channels]
                print(f"  Dominant color channels: {dominant_colors}")
        
        print(f"  ✓ {color_name.capitalize()} generation successful!")
        
    except Exception as e:
        print(f"  ✗ Error generating {color_name} samples: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Testing generate_samples method with different color covariates...
# Content covariate names: ['Intercept', 'C(color_name)[T.green]', 'C(color_name)[T.red]', 'C(color_name)[T.yellow]']
# Content covariate shape: (50000, 4)
#
# Generating red samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.188, 0.052, 0.056]
#   Dominant color channels: ['Red', 'Red', 'Red', 'Red', 'Red']
#   ✓ Red generation successful!
#
# Generating green samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.052, 0.197, 0.055]
#   Dominant color channels: ['Green', 'Green', 'Green', 'Green', 'Green']
#   ✓ Green generation successful!
#
# Generating blue samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.053, 0.054, 0.193]
#   Dominant color channels: ['Blue', 'Blue', 'Blue', 'Blue', 'Blue']
#   ✓ Blue generation successful!
#
# Generating yellow samples...
#   Generated images shape: (5, 3, 28, 28)
#   Average RGB values: [0.188, 0.190, 0.056]
#   Dominant color channels: ['Green', 'Green', 'Green', 'Red', 'Green']
#   ✓ Yellow generation successful!

# %% [markdown]
# ## Compare Generated Images Across Colors

# %%
# Compare generations across colors
print("\nComparing generated samples across colors...")

# Compare image RGB statistics
print("Image color analysis:")
color_stats = {}

for color_name, samples in generated_results.items():
    if "visual_colored_mnist" in samples:
        images = samples["visual_colored_mnist"]
        if len(images.shape) == 4:
            # Calculate color statistics
            mean_rgb = images.mean(axis=(0, 2, 3))  # Mean over batch and spatial
            std_rgb = images.std(axis=(0, 2, 3))   # Std over batch and spatial
            
            color_stats[color_name] = {
                'mean_rgb': mean_rgb,
                'std_rgb': std_rgb
            }
            
            print(f"  {color_name.capitalize()}: RGB mean=[{mean_rgb[0]:.3f}, {mean_rgb[1]:.3f}, {mean_rgb[2]:.3f}], "
                  f"std=[{std_rgb[0]:.3f}, {std_rgb[1]:.3f}, {std_rgb[2]:.3f}]")

# Create a summary DataFrame
if color_stats:
    summary_data = []
    for color, stats in color_stats.items():
        summary_data.append({
            'color': color,
            'red_mean': stats['mean_rgb'][0].item(),
            'green_mean': stats['mean_rgb'][1].item(),
            'blue_mean': stats['mean_rgb'][2].item(),
            'dominant_channel': ['red', 'green', 'blue'][stats['mean_rgb'].argmax()]
        })
    
    summary_df = pd.DataFrame(summary_data)
    print("\nGenerated Image Color Summary:")
    display(summary_df)
# Out:
# Comparing generated samples across colors...
# Image color analysis:
#   Red: RGB mean=[0.188, 0.052, 0.056], std=[0.200, 0.063, 0.064]
#   Green: RGB mean=[0.052, 0.197, 0.055], std=[0.064, 0.217, 0.067]
#   Blue: RGB mean=[0.053, 0.054, 0.193], std=[0.061, 0.065, 0.206]
#   Yellow: RGB mean=[0.188, 0.190, 0.056], std=[0.201, 0.202, 0.064]
#
# Generated Image Color Summary:
#     color  red_mean  green_mean  blue_mean dominant_channel
# 0     red  0.187970    0.052405   0.056216              red
# 1   green  0.052092    0.196859   0.055474            green
# 2    blue  0.052828    0.054005   0.193139             blue
# 3  yellow  0.187714    0.189585   0.056361            green

# %% [markdown]
# ## Visualize Generated Samples

# %%
# Visualize generated samples
if generated_results and MATPLOTLIB_AVAILABLE:
    print("Visualizing generated samples...")
    
    # Create visualization of generated samples
    fig, axes = plt.subplots(len(generated_results), min(n_gen_samples, 4), 
                           figsize=(12, 3 * len(generated_results)))
    
    if len(generated_results) == 1:
        axes = axes.reshape(1, -1)
    
    for row, (color_name, samples) in enumerate(generated_results.items()):
        if "visual_colored_mnist" in samples:
            images = samples["visual_colored_mnist"]
            
            for col in range(min(images.shape[0], 4)):
                img = images[col]
                
                # Convert from tensor format [C, H, W] to [H, W, C] for matplotlib
                if len(img.shape) == 3:
                    img_display = img.transpose(1, 2, 0)
                else:
                    img_display = img
                
                # Clip values to [0, 1] range
                img_display = np.clip(img_display, 0, 1)
                
                axes[row, col].imshow(img_display)
                axes[row, col].set_title(f"Generated {color_name}")
                axes[row, col].axis('off')
    
    plt.tight_layout()
    plt.suptitle('Generated Colored MNIST Samples by Color Covariate', y=1.02, fontsize=16)
    plt.show()
    
    print("✓ Generated samples visualization completed!")
else:
    print("Visualization skipped (matplotlib not available or no samples generated)")
# Out:
# Visualizing generated samples...
# ✓ Generated samples visualization completed!
