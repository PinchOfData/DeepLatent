# %%
# Load a random sample of speeches pronounced in the floor of the US Congress between 1994 and 2024
import pandas as pd
df = pd.read_csv('../data/us_congress_speeches_sample.csv')

print("Number of speeches: {}".format(len(df)))

from deeplatent import Corpus, GTM
from deeplatent import bert_embeddings_from_list
from sklearn.feature_extraction.text import CountVectorizer
import torch

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false" # to avoid some warnings

def embed_fn_bert(texts):
    return bert_embeddings_from_list(
        texts=texts,
        sbert_model_to_load="paraphrase-multilingual-mpnet-base-v2",
        batch_size=8,
        max_seq_length=128,
        device="cuda" if torch.cuda.is_available() else "cpu"
    )

# Create vectorizer
default_vectorizer = CountVectorizer()

# Define modalities
modalities = {
    "text": {
        "column": "doc_clean",
        "views": {
            "embedding": {
                "type": "embedding",
                "embed_fn": embed_fn_bert
            },
            "bow": {
                "type": "bow",
                "vectorizer": default_vectorizer
            }
        }
    }
}

# Create dataset
train_dataset = Corpus(df, modalities=modalities)
# Out:
# Number of speeches: 28731
# README.md: 0.00B [00:00, ?B/s]
# /mnt/c/Users/Gauthier/Desktop/DeepLatent/deeplatent/utils.py:158: UserWarning: the longest document in your collection has 3388 words, the model instead truncates to 128 tokens.
#   warnings.warn(
# Batches:   0%|          | 0/3592 [00:00<?, ?it/s]

# %% [raw]
# import pickle
#
# # Save
# with open('train_dataset.pkl', 'wb') as f:
#     pickle.dump(train_dataset, f)
#
# # Load
# with open('train_dataset.pkl', 'rb') as f:
#     train_dataset = pickle.load(f)

# %%
encoder_args = {
    "text_embedding": {
        "hidden_dims": [256,64],
        "activation": "relu",
        "bias": True,
        "dropout": 0.2
    }
}

decoder_args = {
    "text_bow": {
        "hidden_dims": [64,256],
        "activation": "relu",
        "bias": True,
        "dropout": 0.2
    }
}

# %%
# Train the model
tm = GTM(
    train_data=train_dataset,
    n_topics=20,
    ae_type="wae",
    encoder_args=encoder_args,
    decoder_args=decoder_args
)
# Out:
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Step   1000	Mean Training Loss:8.2189474
# Rec Loss:8.1180105
# Divergence Loss:0.1009365
# Pred Loss:0.0000000
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
#
lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Step   7000	Mean Training Loss:7.9380579
# Rec Loss:7.8419847
# Divergence Loss:0.0960734
# Pred Loss:0.0000000
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Step   8000	Mean Training Loss:8.0275793
# Rec Loss:7.9078760
# Divergence Loss:0.1197034
# Pred Loss:0.0000000
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Step   9000	Mean Training Loss:7.9854250
# Rec Loss:7.8742390
# Divergence Loss:0.1111862
# Pred Loss:0.0000000
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Step  10000	Mean Training Loss:7.8852859
# Rec Loss:7.7666731
# Divergence Loss:0.1186126
# Pred Loss:0.0000000

# %%
print(
    "\n".join(
        [
            "{}: {}".format(str(k), str(v))
            for k, v in tm.get_topic_words(topK=5).items()
        ]
    )
)
# Out:
# Topic_0: ['budget', 'go', 'cut', 'bill', 'debt']
# Topic_1: ['service', 'community', 'recognize', 'honor', 'career']
# Topic_2: ['student', 'school', 'win', 'team', 'award']
# Topic_3: ['program', 'provide', 'health', 'care', 'bill']
# Topic_4: ['bill', 'energy', 'business', 'legislation', 'program']
# Topic_5: ['follow', 'business', 'hour', 'bill', 'leader']
# Topic_6: ['school', 'student', 'child', 'teacher', 'education']
# Topic_7: ['energy', 'oil', 'price', 'gas', 'go']
# Topic_8: ['child', 'school', 'go', 'health', 'care']
# Topic_9: ['crime', 'law', 'criminal', 'enforcement', 'violence']
# Topic_10: ['energy', 'oil', 'go', 'price', 'gas']
# Topic_11: ['armenian', 'anniversary', 'world', 'nation', 'peace']
# Topic_12: ['plan', 'continue', 'anniversary', 'other', 'country']
# Topic_13: ['resolution', 'bill', 'other', 'budget', 'leader']
# Topic_14: ['right', 'law', 'woman', 'go', 'other']
# Topic_15: ['go', 'war', 'get', 'country', 'military']
# Topic_16: ['program', 'service', 'community', 'recognize', 'provide']
# Topic_17: ['budget', 'spending', 'resolution', 'deficit', 'bill']
# Topic_18: ['go', 'know', 'get', 'budget', 'come']
# Topic_19: ['life', 'family', 'love', 'honor', 'know']

# %%
# We use multilingual embeddings as input (for encoding) and decode Bag of Words matrices.
# This means the model can also predict topic shares out of sample for other languages (e.g., French).

import pandas as pd
import numpy as np

# Define the list of French sentences
sentences = [
    "L'arme nucléaire est un atout géopolitique indéniable.",
    "Cette équipe de football est incroyable.",
    "La guerre entre ces deux pays sera meurtrière.",
    "Il faut réformer l'école publique avant que ce ne soit trop tard.",
    "Les prix de l'électricité ne font qu'augmenter."
]

# Create the DataFrame
df2 = pd.DataFrame({'speech': sentences})

modalities = {
    "text": {
        "column": "speech",
        "views": {
            "embedding": {
                "type": "embedding",
                "embed_fn": embed_fn_bert
            }
        }
    }
}

# Create dataset
french_dataset = Corpus(df2, modalities=modalities)

the_topic_shares = tm.get_doc_topic_distribution(french_dataset)

# Get the top topic per document
top_topics = np.argmax(the_topic_shares, axis=1)

# Get topic words dictionary
topic_words = tm.get_topic_words(topK=5)

# Format and print the results
for i, (sentence, topic_id) in enumerate(zip(sentences, top_topics)):
    topic_id = int(topic_id)  # Cast to plain Python int
    words = ", ".join(topic_words["Topic_{}".format(topic_id)])
    print(f"Sentence {i+1}: {sentence}")
    print(f"→ Top Topic {topic_id}: {words}\n")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Sentence 1: L'arme nucléaire est un atout géopolitique indéniable.
# → Top Topic 13: resolution, bill, other, budget, leader
#
# Sentence 2: Cette équipe de football est incroyable.
# → Top Topic 2: student, school, win, team, award
#
# Sentence 3: La guerre entre ces deux pays sera meurtrière.
# → Top Topic 15: go, war, get, country, military
#
# Sentence 4: Il faut réformer l'école publique avant que ce ne soit trop tard.
# → Top Topic 8: child, school, go, health, care
#
# Sentence 5: Les prix de l'électricité ne font qu'augmenter.
# → Top Topic 7: energy, oil, price, gas, go
# /home/gauthier/miniconda3/envs/gtm/lib/python3.13/multiprocessing/popen_fork.py:67: DeprecationWarning: This process (pid=4880) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
